# %%
import pandas as pd

# %%
ls records
# Out:
# 9-19-2021.xlsx

# %%
df_movie = pd.read_excel('records/9-19-2021.xlsx',sheet_name=0)
df_movie
# Out:
#                 标题                                                 简介  豆瓣评分  \
# 0              蓝风筝           1993 / 中国大陆 中国香港 / 剧情 历史 / 田壮壮 / 吕丽萍 濮存昕   8.8
# 1          尚气与十环传奇      2021 / 美国 澳大利亚 / 动作 科幻 冒险 / 德斯汀·克里顿 / 刘思慕 梁朝伟   0.0
# 2          一江春水向东流                 1947 / 中国大陆 / 剧情 / 蔡楚生 郑君里 / 白杨 陶金   8.5
# 3             开国大典          1989 / 中国大陆 / 剧情 历史 战争 / 李前宽 肖桂云 / 古月 孙飞虎   7.6
# 4              大决战                2021 / 中国大陆 / 剧情 历史 / 高希希 / 唐国强 王劲松   7.8
# ..             ...                                                ...   ...
# 120      如果和母亲一起生活              2015 / 日本 / 剧情 家庭 / 山田洋次 / 吉永小百合 二宫和也   7.5
# 121           家族之苦                2016 / 日本 / 喜剧 家庭 / 山田洋次 / 桥爪功 吉行和子   8.1
# 122           天地明察            2012 / 日本 / 剧情 传记 历史 / 泷田洋二郎 / 冈田准一 宫崎葵   7.2
# 123        春夏秋冬又一春                  2003 / 韩国 德国 / 剧情 / 金基德 / 吴永洙 金基德   8.5
# 124  永远的教皇：约翰·保罗二世  2006 / 意大利 波兰 加拿大 / 传记 / 乔科摩·巴蒂亚托 / 彼得·亚当奇克 Da...   8.7
#
# ...

# %%
df_read = pd.read_excel('records/9-19-2021.xlsx',sheet_name=6)
df_read
# Out:
#                                                    标题  \
# 0                                            老舍之死口述实录
# 1    Geometric Modeling in Probability and Statistics
# 2                       Docker in Action, 2nd Edition
# 3               Statistical Data Analysis and Entropy
# 4                          When China Rules the World
# ..                                                ...
# 301                                          中国文化要义新编
# 302                                           这个世界会好吗
# 303                                         中国思想史（上下）
# 304                                              资治通鉴
# 305                                               红楼梦
#
#                                                     简介  豆瓣评分  \
# 0                                 傅光明 / 2009 / 复旦大学出版社   8.7
# 1    Ovidiu Calin Constantin Udriste / 2014 / Springer   0.0
# 2    Jeff Nickoloff Stephen Kuenzli / 2019 / Mannin...   7.8
# 3                                                  NaN   0.0
# ...

# %%
df_read.head(20)
# Out:
#                                                   标题  \
# 0                                           老舍之死口述实录
# 1   Geometric Modeling in Probability and Statistics
# 2                      Docker in Action, 2nd Edition
# 3              Statistical Data Analysis and Entropy
# 4                         When China Rules the World
# 5                               Who Rules the World?
# 6                                        联共（布）党史简明教程
# 7                   Handbook of Differential Entropy
# 8                                               革命年代
# 9                                              砸烂旧世界
# 10                          中華人民共和國史 第八卷 難以繼續的「繼續革命」
# 11                                中華人民共和國史 第五卷 歷史的變局
# 12                                中華人民共和國史 第四卷 烏托邦運動
# 13             Programming PyTorch for Deep Learning
# 14                                中華人民共和國史 第三卷 思考與選擇
# 15                              中華人民共和國史 第二卷 向社會主義過渡
# 16                          The Authoritarian Moment
# ...
